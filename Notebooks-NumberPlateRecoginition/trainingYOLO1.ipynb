# %% [markdown]
# # Yolo Training NoteBook

# %%
import os
os.getcwd()

# %%
os.chdir('/content/drive/MyDrive/NumberPlateDetection/5. Number Plate Recognition/yolo_training/yolov5')

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/NumberPlateDetection/5. Number Plate Recognition/yolo_training/yolov5'

# %% [markdown]
# ### Cloning Yolo Reopsitory

# %%
#!git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %% [markdown]
# ### Intalling Requirement Files

# %%
#%%bash
#cd yolov5
#pip install -r requirements.txt

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/NumberPlateDetection/5. Number Plate Recognition/yolo_training/yolov5'

# %% [markdown]
# # Training YOLO Model

# %%
# !python train.py --data data.yaml --weights yolov5s.pt --batch-size 8 --name Model --img 640 --epochs 200
# Out:
# train: weights=yolov5s.pt, cfg=, data=data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=Model, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch origin' timed out after 5 seconds
# requirements: YOLOv5 requirements "ipython" "thop>=0.1.1" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#
# requirements: 2 packages updated per /content/drive/MyDrive/NumberPlateDetection/5. Number Plate Recognition/yolo_training/yolov5/requirements.txt
# ...

# %% [markdown]
# # Saving the Weights as ONNX
#
# onnx can be used with opencv

# %%
! python export.py --weights runs/train/Model12/weights/best.pt --include onnx --simplify
# Out:
# export: data=data/coco128.yaml, weights=['runs/train/Model12/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['onnx']
# fatal: cannot change to '/content/drive/MyDrive/NumberPlateDetection/5.': No such file or directory
# YOLOv5 🚀 2022-11-13 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from runs/train/Model12/weights/best.pt with output shape (1, 25200, 6) (13.8 MB)
# requirements: YOLOv5 requirement "onnx" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#
# requirements: 1 package updated per ['onnx']
# ...
